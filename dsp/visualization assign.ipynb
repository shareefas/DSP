# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[2,3,4,5,6]
plt.xlabel('score')
plt.ylabel('overs')
plt.title('funny creatd')
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[2,3,4,5,6]
plt.xlabel('score')
plt.ylabel('overs')
plt.title('funny created')
plt.plot(x,y,'r',linewidth=4,linestyle="dashed")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[2,3,4,5,6]
plt.xlabel('score')
plt.ylabel('overs')
plt.title('funny created')
plt.plot(x,y,marker='+',markersize='10',markeredgecolor='black')
plt.show()

# %%
import matplotlib.pyplot as pd
import numpy as np
overrange1=['1-10','11-20','21-30','31-40']
runscored=[23,43,55,66]
plt.bar(overrange1,runscored,width=0.8,color=['g','b','r','y'])
#default width=0.5
plt.xlabel('overs')
plt.ylabel('runscored')
plt.title('bullet')
plt.show()

# %%
import matplotlib.pyplot as pd
import numpy as np
overrange1=['1-10','11-20','21-30','31-40']
runscored=[23,43,55,66]
plt.barh(overrange1,runscored)
#default width=0.5
plt.xlabel('overs')
plt.ylabel('runscored')
plt.title('bullet')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(1,51,5)
plt.bar(x,width=3,color='r',label='afganistan')
plt.bar(x+3,b,width=3,color='g',label='India')
plt.xlabel('overs')
plt.ylabel('runs scored')
plt.title('scoring chart india to afganistn')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7888/983307906.py in <module>
#       2 import numpy as np
#       3 x=np.linspace(1,51,5)
# ----> 4 plt.bar(x,width=3,color='r',label='afganistan')
#       5 plt.bar(x+3,b,width=3,color='g',label='India')
#       6 plt.xlabel('overs')
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
import matplotlib.pyplot as plt
slices=[30,40,20,10]
dept=['hod','dean','dsw','dfdf']
places=['red','blue','green','orange']
exp=[0,0.2,0.3,0]
plt.pie(slices,labels=dept,colors=places,startangle=90,explode=exp,shadow=True,autopct='%.1f%%')
plt.title('rgukt')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
x=range(4)
y=[20.5,32,33,44]
plt.xticks([0,1,2,3])
plt.bar(x,y,width=0.25)
plt.show()

# %%
import matplotlib.pyplot as plt
val1=[2,3,4,5,6]
val2=[7,20,25,33,45]
val3=[10,30,40,50,60]
data=[val1,val2,val3]
plt.boxplot(data,labels=['series1','series2','series3'],)
plt.show()

# %%
import matplotlib.pyplot as plt
val1=[2,3,4,5,6]
val2=[7,20,25,33,45]
val3=[10,30,40,50,60]
data=[val1,val2,val3]
plt.boxplot(data,labels=['series1','series2','series3'],patch_artist=True,notch=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d0f9784700>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d0f9784e20>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x1d0f9784340>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1d0f9791580>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1d0f9791910>,
# ...
#  'means': []}

# %%
import matplotlib.pyplot as plt

x=[25,44,55,66]
y=[3,5,6,7]
plt.scatter(x, y, color='red',marker='+')
plt.xlabel('age')
plt.ylabel('no of employe')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[22,33,44,55]
y=[3,4,5,6]
plt.scatter(x,y)
plt.xlabel('age')
plt.ylabel('akfjdkfjkfj')

plt.show()

# %%
impoort pandas as pd
d={'col1':[1,2,3,4,5],'col2':[6,7,8,9,10],'col3':[22,33,44,55,66]}
df=pd.DataFrame(data=d)
print(df)
# Out:
#   File "C:\Users\shaik\AppData\Local\Temp/ipykernel_7888/3829423288.py", line 1
#     impoort pandas as pd
#             ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

d = {'col1': [1, 2, 3, 4, 7], 'col2': [4, 5, 6, 9, 5], 'col3': [7, 8, 12, 1, 11]}

df = pd.DataFrame(data=d)

print(df)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7888/3161387801.py in <module>
# ----> 1 d
#
# NameError: name 'd' is not defined

# %%
import matplotlib.pyplot as plt
x=[1,2,3]
y=[2,3.5,5]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3]
y=[1,1.5,5]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[25,68,65,77,44,88,99]
plt.xlabel('overs')
plt.ylabel('run scored')
plt.title('over wise runf scored/india vs england')
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[20,33,44,55,76]
y=[12,23,44,55,66]
plt.xlabel('marks of mid maths subject')
plt.ylabel('student names')
plt.title('secshu sir is good paper correction')
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
arange1=['1-10','11-20','21-30']
runscored=[23,43,50]
plt.bar(arange1,runscored)
plt.xlabel('arange1')
plt.ylabel('runscored')
plt.title('scprecarasdt')
plt.show()
